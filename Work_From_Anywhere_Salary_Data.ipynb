# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Work_From_Anywhere_Salary_Data.csv')

# %%
df
# Out:
#        Company          Job Title    Industry       Location Employment Type  \
# 0    Microsoft       Data Analyst       Media         Austin       Part-time
# 1        Apple     Data Scientist      Retail  San Francisco       Part-time
# 2       Amazon  Software Engineer  Healthcare  San Francisco       Full-time
# 3        Tesla       Data Analyst      Retail         Austin        Contract
# 4        Adobe    DevOps Engineer  Healthcare       New York        Contract
# ..         ...                ...         ...            ...             ...
# 495     Google        UX Designer      Retail  San Francisco       Full-time
# 496  Microsoft    Product Manager     Finance  San Francisco       Part-time
# 497     Amazon  Software Engineer      Retail        Seattle       Part-time
# 498        IBM       Data Analyst  Healthcare       New York       Full-time
# 499        IBM  Software Engineer      Retail         Remote       Part-time
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Company          Job Title    Industry       Location Employment Type  \
# 0    Microsoft       Data Analyst       Media         Austin       Part-time
# 1        Apple     Data Scientist      Retail  San Francisco       Part-time
# 2       Amazon  Software Engineer  Healthcare  San Francisco       Full-time
# 3        Tesla       Data Analyst      Retail         Austin        Contract
# 4        Adobe    DevOps Engineer  Healthcare       New York        Contract
# ..         ...                ...         ...            ...             ...
# 495     Google        UX Designer      Retail  San Francisco       Full-time
# 496  Microsoft    Product Manager     Finance  San Francisco       Part-time
# 497     Amazon  Software Engineer      Retail        Seattle       Part-time
# 498        IBM       Data Analyst  Healthcare       New York       Full-time
# 499        IBM  Software Engineer      Retail         Remote       Part-time
#
# ...

# %%
df.shape
# Out:
# (500, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 14 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Company                        500 non-null    object
#  1   Job Title                      500 non-null    object
#  2   Industry                       500 non-null    object
#  3   Location                       500 non-null    object
#  4   Employment Type                500 non-null    object
#  5   Experience Level               500 non-null    object
#  6   Remote Flexibility             500 non-null    object
#  7   Salary (Annual)                500 non-null    float64
#  8   Currency                       500 non-null    object
#  9   Years of Experience            500 non-null    float64
#  10  Job Satisfaction Score (1-10)  500 non-null    int64
#  11  Tech Stack                     500 non-null    object
# ...

# %%
df.dtypes
# Out:
# Company                           object
# Job Title                         object
# Industry                          object
# Location                          object
# Employment Type                   object
# Experience Level                  object
# Remote Flexibility                object
# Salary (Annual)                  float64
# Currency                          object
# Years of Experience              float64
# Job Satisfaction Score (1-10)      int64
# Tech Stack                        object
# Perks                             object
# Last Promotion (Years Ago)       float64
# dtype: object

# %%
missing_value = df.isnull().sum()
print('Missing value per column:', missing_value)
# Out:
# Missing value per column: Company                          0
# Job Title                        0
# Industry                         0
# Location                         0
# Employment Type                  0
# Experience Level                 0
# Remote Flexibility               0
# Salary (Annual)                  0
# Currency                         0
# Years of Experience              0
# Job Satisfaction Score (1-10)    0
# Tech Stack                       0
# Perks                            0
# Last Promotion (Years Ago)       0
# dtype: int64

# %%
counts = df['Employment Type'].value_counts()

plt.figure(figsize=(10,5))
counts.plot(kind = 'bar', color = 'skyblue')

plt.xlabel('Employment Type')
plt.ylabel('counts')
plt.title('Employment Type Distribution')
plt.show()

# %%
plt.figure(figsize = (7,4))
df['Remote Flexibility'].value_counts().plot(kind='bar')
plt.xlabel('Distribution of Remote Flexibility')
plt.ylabel('Count')
plt.tile('Remote Count')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[31], line 5
#       3 plt.xlabel('Distribution of Remote Flexibility')
#       4 plt.ylabel('Count')
# ----> 5 plt.tile('Remote Count')
#       6 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'tile'

# %%
plt.figure(figsize=(12,6))
sns.barplot(x='Remote Flexibility', y='Salary (Annual)', data=df)
plt.title('Distribution of Remote Flexibility based on salary')
# Out:
# Text(0.5, 1.0, 'Distribution of Remote Flexibility based on salary')

# %%
plt.figure(figsize=(15,8))
sns.boxplot(x='Job Satisfaction Score (1-10)', y='Salary (Annual)', data=df)
plt.title('Distribution of Job satisfaction with their salary')
# Out:
# Text(0.5, 1.0, 'Distribution of Job satisfaction with their salary')

# %%
plt.figure(figsize=(25,10))
sns.boxplot(x='Years of Experience', y='Salary (Annual)', data=df)
plt.title('Salary by Experience Level')
plt.xlabel('Years of Experience')
plt.ylabel('Salary (Annual)')
plt.show()
